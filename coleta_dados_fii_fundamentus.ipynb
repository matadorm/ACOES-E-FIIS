# %% [markdown]
# # Importação de bibliotecas

# %%
import http.cookiejar
import urllib.request
import urllib.parse
import re
from collections import OrderedDict
from lxml.html import fragment_fromstring
from decimal import Decimal
import pandas as pd

# %% [markdown]
# # Coleta de dados

# %%
def todecimal(string):
  string = string.replace('.', '')
  string = string.replace(',', '.')

  if (string.endswith('%')):
    string = string[:-1]
    return Decimal(string) #/ 100
  else:
    return Decimal(string)

def get_data(*args, **kwargs):
    url = 'http://www.fundamentus.com.br/fii_resultado.php'
    cookie_jar = http.cookiejar.CookieJar()
    opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cookie_jar))
    opener.addheaders = [('User-agent', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'),
                         ('Accept', 'text/html, text/plain, text/css, text/sgml, */*;q=0.01')]

    data = {}

    with opener.open(url, urllib.parse.urlencode(data).encode('UTF-8')) as link:
        content = link.read().decode('ISO-8859-1')

    pattern = re.compile('<table id="tabelaResultado".*</table>', re.DOTALL)
    content = re.findall(pattern, content)[0]
    page = fragment_fromstring(content)
    result = OrderedDict()

    for rows in page.xpath('//tbody')[0].findall("tr"):
        result.update({rows.getchildren()[0][0].getchildren()[0].text: {
            'Segmento': rows.getchildren()[1].text,
            'Cotacao': todecimal(rows.getchildren()[2].text),
            'FFO Yield': todecimal(rows.getchildren()[3].text),
            'Dividend Yield': todecimal(rows.getchildren()[4].text),
            'P/VP': todecimal(rows.getchildren()[5].text),
            'Valor de Mercado': todecimal(rows.getchildren()[6].text),
            'Liquidez': todecimal(rows.getchildren()[7].text),
            'Qtd de imóveis': todecimal(rows.getchildren()[8].text),
            'Preço do m2': todecimal(rows.getchildren()[9].text),
            'Aluguel por m2': todecimal(rows.getchildren()[10].text),
            'Cap Rate': todecimal(rows.getchildren()[11].text),
            'Vacância Média': todecimal(rows.getchildren()[12].text)
        }})
    
    return result

# %%
data = get_data()
data
# Out:
# OrderedDict([('AAZQ11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('7.39'),
#                'FFO Yield': Decimal('20.37'),
#                'Dividend Yield': Decimal('17.51'),
#                'P/VP': Decimal('0.78'),
#                'Valor de Mercado': Decimal('177636000'),
#                'Liquidez': Decimal('1261870'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ABCP11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('67.50'),
#                'FFO Yield': Decimal('10.17'),
#                'Dividend Yield': Decimal('9.25'),
#                'P/VP': Decimal('0.67'),
#                'Valor de Mercado': Decimal('317863000'),
#                'Liquidez': Decimal('57613'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('4442.43'),
#                'Aluguel por m2': Decimal('567.65'),
#                'Cap Rate': Decimal('12.78'),
#                'Vacância Média': Decimal('2.44')}),
#              ('AEFI11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('174.90'),
#                'FFO Yield': Decimal('8.78'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.20'),
#                'Valor de Mercado': Decimal('411893000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('7'),
#                'Preço do m2': Decimal('4312.36'),
#                'Aluguel por m2': Decimal('390.35'),
#                'Cap Rate': Decimal('9.05'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AFCR11',
#               {'Segmento': None,
#                'Cotacao': Decimal('103.15'),
#                'FFO Yield': Decimal('7.43'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.03'),
#                'Valor de Mercado': Decimal('394422000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AFHI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('97.17'),
#                'FFO Yield': Decimal('9.76'),
#                'Dividend Yield': Decimal('11.51'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('388384000'),
#                'Liquidez': Decimal('1484810'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AFOF11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('91.60'),
#                'FFO Yield': Decimal('0.63'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('10.91'),
#                'Valor de Mercado': Decimal('1390540000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AGCX11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('1235.50'),
#                'FFO Yield': Decimal('0.75'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('11.41'),
#                'Valor de Mercado': Decimal('15425600000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('50'),
#                'Preço do m2': Decimal('198010.00'),
#                'Aluguel por m2': Decimal('1975.52'),
#                'Cap Rate': Decimal('1.00'),
#                'Vacância Média': Decimal('0.43')}),
#              ('AGRX11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('9.71'),
#                'FFO Yield': Decimal('13.84'),
#                'Dividend Yield': Decimal('16.55'),
#                'P/VP': Decimal('0.96'),
#                'Valor de Mercado': Decimal('173840000'),
#                'Liquidez': Decimal('295761'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AIEC11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('53.21'),
#                'FFO Yield': Decimal('19.00'),
#                'Dividend Yield': Decimal('17.66'),
#                'P/VP': Decimal('0.63'),
#                'Valor de Mercado': Decimal('256738000'),
#                'Liquidez': Decimal('337791'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('10715.20'),
#                'Aluguel por m2': Decimal('2098.55'),
#                'Cap Rate': Decimal('19.58'),
#                'Vacância Média': Decimal('0.00')}),
#              ('AJFI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('8.28'),
#                'FFO Yield': Decimal('4.50'),
#                'Dividend Yield': Decimal('6.57'),
#                'P/VP': Decimal('0.66'),
#                'Valor de Mercado': Decimal('261863000'),
#                'Liquidez': Decimal('845356'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('3.62'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ALMI11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('626.01'),
#                'FFO Yield': Decimal('4.93'),
#                'Dividend Yield': Decimal('0.99'),
#                'P/VP': Decimal('0.29'),
#                'Valor de Mercado': Decimal('69597900'),
#                'Liquidez': Decimal('23974'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('3875310.00'),
#                'Aluguel por m2': Decimal('547722.35'),
#                'Cap Rate': Decimal('14.13'),
#                'Vacância Média': Decimal('54.50')}),
#              ('ALZC11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('97.00'),
#                'FFO Yield': Decimal('14.54'),
#                'Dividend Yield': Decimal('3.60'),
#                'P/VP': Decimal('0.96'),
#                'Valor de Mercado': Decimal('37772700'),
#                'Liquidez': Decimal('41566'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ALZM11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('8.00'),
#                'FFO Yield': Decimal('7.24'),
#                'Dividend Yield': Decimal('12.13'),
#                'P/VP': Decimal('0.95'),
#                'Valor de Mercado': Decimal('121444000'),
#                'Liquidez': Decimal('204345'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ALZR11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('108.54'),
#                'FFO Yield': Decimal('7.62'),
#                'Dividend Yield': Decimal('8.33'),
#                'P/VP': Decimal('1.02'),
#                'Valor de Mercado': Decimal('1166750000'),
#                'Liquidez': Decimal('2247030'),
#                'Qtd de imóveis': Decimal('14'),
#                'Preço do m2': Decimal('5303.30'),
#                'Aluguel por m2': Decimal('410.01'),
#                'Cap Rate': Decimal('7.73'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ANCR11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('77.99'),
#                'FFO Yield': Decimal('384.83'),
#                'Dividend Yield': Decimal('1.23'),
#                'P/VP': Decimal('0.02'),
#                'Valor de Mercado': Decimal('52126600'),
#                'Liquidez': Decimal('13'),
#                'Qtd de imóveis': Decimal('5'),
#                'Preço do m2': Decimal('213.44'),
#                'Aluguel por m2': Decimal('1304.06'),
#                'Cap Rate': Decimal('610.98'),
#                'Vacância Média': Decimal('4.42')}),
#              ('APTO11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('9.61'),
#                'FFO Yield': Decimal('10.74'),
#                'Dividend Yield': Decimal('10.87'),
#                'P/VP': Decimal('0.95'),
#                'Valor de Mercado': Decimal('44323500'),
#                'Liquidez': Decimal('23352'),
#                'Qtd de imóveis': Decimal('4'),
#                'Preço do m2': Decimal('17757.20'),
#                'Aluguel por m2': Decimal('1193.43'),
#                'Cap Rate': Decimal('6.72'),
#                'Vacância Média': Decimal('0.00')}),
#              ('APXM11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('99.99'),
#                'FFO Yield': Decimal('7.09'),
#                'Dividend Yield': Decimal('5.75'),
#                'P/VP': Decimal('1.04'),
#                'Valor de Mercado': Decimal('175982000'),
#                'Liquidez': Decimal('111929'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('1735.14'),
#                'Aluguel por m2': Decimal('119.17'),
#                'Cap Rate': Decimal('6.87'),
#                'Vacância Média': Decimal('10.49')}),
#              ('ARCT11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('87.13'),
#                'FFO Yield': Decimal('13.47'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.86'),
#                'Valor de Mercado': Decimal('323093000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('12'),
#                'Preço do m2': Decimal('1225.85'),
#                'Aluguel por m2': Decimal('124.53'),
#                'Cap Rate': Decimal('10.16'),
#                'Vacância Média': Decimal('3.74')}),
#              ('AROA11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('1.00'),
#                'FFO Yield': Decimal('5.67'),
#                'Dividend Yield': Decimal('4.13'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('170034000'),
#                'Liquidez': Decimal('5209'),
#                'Qtd de imóveis': Decimal('6'),
#                'Preço do m2': Decimal('3695.35'),
#                'Aluguel por m2': Decimal('244.92'),
#                'Cap Rate': Decimal('6.63'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ARRI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('9.05'),
#                'FFO Yield': Decimal('7.90'),
#                'Dividend Yield': Decimal('12.34'),
#                'P/VP': Decimal('1.03'),
#                'Valor de Mercado': Decimal('138776000'),
#                'Liquidez': Decimal('460029'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ARXD11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('98.00'),
#                'FFO Yield': Decimal('7.94'),
#                'Dividend Yield': Decimal('11.84'),
#                'P/VP': Decimal('0.99'),
#                'Valor de Mercado': Decimal('64179700'),
#                'Liquidez': Decimal('35893'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ASMT11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('39.69'),
#                'FFO Yield': Decimal('6.64'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.44'),
#                'Valor de Mercado': Decimal('42915100'),
#                'Liquidez': Decimal('11619'),
#                'Qtd de imóveis': Decimal('3'),
#                'Preço do m2': Decimal('3697.66'),
#                'Aluguel por m2': Decimal('751.73'),
#                'Cap Rate': Decimal('20.33'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ASRF11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('10840.80'),
#                'FFO Yield': Decimal('-0.19'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.11'),
#                'Valor de Mercado': Decimal('31893600'),
#                'Liquidez': Decimal('103852'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('4295.15'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ATSA11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('55.79'),
#                'FFO Yield': Decimal('-0.07'),
#                'Dividend Yield': Decimal('1.27'),
#                'P/VP': Decimal('0.73'),
#                'Valor de Mercado': Decimal('97696200'),
#                'Liquidez': Decimal('189'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('2868.74'),
#                'Aluguel por m2': Decimal('13.19'),
#                'Cap Rate': Decimal('0.46'),
#                'Vacância Média': Decimal('17.12')}),
#              ('AURB11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('85.62'),
#                'FFO Yield': Decimal('3.06'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.07'),
#                'Valor de Mercado': Decimal('76640000'),
#                'Liquidez': Decimal('78'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('2247.02'),
#                'Aluguel por m2': Decimal('129.15'),
#                'Cap Rate': Decimal('5.75'),
#                'Vacância Média': Decimal('50.82')}),
#              ('BARI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('81.94'),
#                'FFO Yield': Decimal('9.96'),
#                'Dividend Yield': Decimal('10.13'),
#                'P/VP': Decimal('0.89'),
#                'Valor de Mercado': Decimal('379726000'),
#                'Liquidez': Decimal('756854'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BBFI11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('688.98'),
#                'FFO Yield': Decimal('63.67'),
#                'Dividend Yield': Decimal('35.97'),
#                'P/VP': Decimal('0.31'),
#                'Valor de Mercado': Decimal('89567400'),
#                'Liquidez': Decimal('432829'),
#                'Qtd de imóveis': Decimal('3'),
#                'Preço do m2': Decimal('892.90'),
#                'Aluguel por m2': Decimal('705.29'),
#                'Cap Rate': Decimal('78.99'),
#                'Vacância Média': Decimal('46.50')}),
#              ('BBFO11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('71.00'),
#                'FFO Yield': Decimal('17.01'),
#                'Dividend Yield': Decimal('10.34'),
#                'P/VP': Decimal('0.89'),
#                'Valor de Mercado': Decimal('284277000'),
#                'Liquidez': Decimal('424204'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BBGO11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('83.89'),
#                'FFO Yield': Decimal('26.29'),
#                'Dividend Yield': Decimal('11.20'),
#                'P/VP': Decimal('0.86'),
#                'Valor de Mercado': Decimal('335993000'),
#                'Liquidez': Decimal('270638'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BBIG11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('9.32'),
#                'FFO Yield': Decimal('0.00'),
#                'Dividend Yield': Decimal('1.70'),
#                'P/VP': Decimal('0.96'),
#                'Valor de Mercado': Decimal('923808000'),
#                'Liquidez': Decimal('487637'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BBPO11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('96.75'),
#                'FFO Yield': Decimal('10.87'),
#                'Dividend Yield': Decimal('2.77'),
#                'P/VP': Decimal('0.96'),
#                'Valor de Mercado': Decimal('1540230000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('62'),
#                'Preço do m2': Decimal('3880.39'),
#                'Aluguel por m2': Decimal('498.90'),
#                'Cap Rate': Decimal('12.86'),
#                'Vacância Média': Decimal('3.14')}),
#              ('BBRC11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('108.71'),
#                'FFO Yield': Decimal('12.04'),
#                'Dividend Yield': Decimal('11.58'),
#                'P/VP': Decimal('1.06'),
#                'Valor de Mercado': Decimal('172849000'),
#                'Liquidez': Decimal('136768'),
#                'Qtd de imóveis': Decimal('20'),
#                'Preço do m2': Decimal('10776.50'),
#                'Aluguel por m2': Decimal('1498.23'),
#                'Cap Rate': Decimal('13.90'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BBVJ11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('62.99'),
#                'FFO Yield': Decimal('3.10'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.88'),
#                'Valor de Mercado': Decimal('197789000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('10021.30'),
#                'Aluguel por m2': Decimal('630.90'),
#                'Cap Rate': Decimal('6.30'),
#                'Vacância Média': Decimal('49.67')}),
#              ('BCFF11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('8.33'),
#                'FFO Yield': Decimal('9.72'),
#                'Dividend Yield': Decimal('10.45'),
#                'P/VP': Decimal('0.88'),
#                'Valor de Mercado': Decimal('1678420000'),
#                'Liquidez': Decimal('2604340'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BCIA11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('104.97'),
#                'FFO Yield': Decimal('9.05'),
#                'Dividend Yield': Decimal('9.26'),
#                'P/VP': Decimal('0.97'),
#                'Valor de Mercado': Decimal('390387000'),
#                'Liquidez': Decimal('991574'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BCRI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('66.56'),
#                'FFO Yield': Decimal('7.98'),
#                'Dividend Yield': Decimal('12.64'),
#                'P/VP': Decimal('0.76'),
#                'Valor de Mercado': Decimal('416524000'),
#                'Liquidez': Decimal('596948'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BICE11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('910.00'),
#                'FFO Yield': Decimal('8.76'),
#                'Dividend Yield': Decimal('9.90'),
#                'P/VP': Decimal('0.91'),
#                'Valor de Mercado': Decimal('95415300'),
#                'Liquidez': Decimal('12405'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BICR11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('58.05'),
#                'FFO Yield': Decimal('19.77'),
#                'Dividend Yield': Decimal('27.50'),
#                'P/VP': Decimal('1.30'),
#                'Valor de Mercado': Decimal('29025000'),
#                'Liquidez': Decimal('891'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BIME11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('7.21'),
#                'FFO Yield': Decimal('12.69'),
#                'Dividend Yield': Decimal('13.38'),
#                'P/VP': Decimal('0.83'),
#                'Valor de Mercado': Decimal('42146800'),
#                'Liquidez': Decimal('69450'),
#                'Qtd de imóveis': Decimal('3'),
#                'Preço do m2': Decimal('302.90'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BIPD11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('988.17'),
#                'FFO Yield': Decimal('-1.57'),
#                'Dividend Yield': Decimal('7.39'),
#                'P/VP': Decimal('1.02'),
#                'Valor de Mercado': Decimal('78456700'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('3'),
#                'Preço do m2': Decimal('5417.49'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLCA11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('102.95'),
#                'FFO Yield': Decimal('-1.12'),
#                'Dividend Yield': Decimal('15.85'),
#                'P/VP': Decimal('0.84'),
#                'Valor de Mercado': Decimal('164720000'),
#                'Liquidez': Decimal('202467'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('38188.90'),
#                'Aluguel por m2': Decimal('3093.36'),
#                'Cap Rate': Decimal('8.10'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLCP11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('91.00'),
#                'FFO Yield': Decimal('5.41'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.81'),
#                'Valor de Mercado': Decimal('208962000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('3014.16'),
#                'Aluguel por m2': Decimal('199.89'),
#                'Cap Rate': Decimal('6.63'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLMC11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('85.75'),
#                'FFO Yield': Decimal('11.10'),
#                'Dividend Yield': Decimal('7.04'),
#                'P/VP': Decimal('0.91'),
#                'Valor de Mercado': Decimal('34257100'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLMG11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('39.04'),
#                'FFO Yield': Decimal('17.40'),
#                'Dividend Yield': Decimal('15.20'),
#                'P/VP': Decimal('0.49'),
#                'Valor de Mercado': Decimal('166654000'),
#                'Liquidez': Decimal('622646'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('194.70'),
#                'Aluguel por m2': Decimal('37.43'),
#                'Cap Rate': Decimal('19.23'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLMO11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('79.99'),
#                'FFO Yield': Decimal('6.12'),
#                'Dividend Yield': Decimal('6.11'),
#                'P/VP': Decimal('0.77'),
#                'Valor de Mercado': Decimal('79575200'),
#                'Liquidez': Decimal('6117'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('9480.80'),
#                'Aluguel por m2': Decimal('804.51'),
#                'Cap Rate': Decimal('8.49'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLMR11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('6.78'),
#                'FFO Yield': Decimal('10.17'),
#                'Dividend Yield': Decimal('4.12'),
#                'P/VP': Decimal('0.84'),
#                'Valor de Mercado': Decimal('173172000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BLUR11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('93.31'),
#                'FFO Yield': Decimal('3.54'),
#                'Dividend Yield': Decimal('10.14'),
#                'P/VP': Decimal('1.08'),
#                'Valor de Mercado': Decimal('8397900'),
#                'Liquidez': Decimal('1303'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BMLC11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('99.81'),
#                'FFO Yield': Decimal('10.17'),
#                'Dividend Yield': Decimal('10.49'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('99650800'),
#                'Liquidez': Decimal('23033'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('16398.90'),
#                'Aluguel por m2': Decimal('1501.95'),
#                'Cap Rate': Decimal('9.16'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BNFS11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('117.40'),
#                'FFO Yield': Decimal('14.63'),
#                'Dividend Yield': Decimal('13.20'),
#                'P/VP': Decimal('1.39'),
#                'Valor de Mercado': Decimal('82180000'),
#                'Liquidez': Decimal('127601'),
#                'Qtd de imóveis': Decimal('18'),
#                'Preço do m2': Decimal('7504.00'),
#                'Aluguel por m2': Decimal('1311.04'),
#                'Cap Rate': Decimal('17.47'),
#                'Vacância Média': Decimal('0.22')}),
#              ('BPFF11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('70.00'),
#                'FFO Yield': Decimal('15.39'),
#                'Dividend Yield': Decimal('10.05'),
#                'P/VP': Decimal('0.91'),
#                'Valor de Mercado': Decimal('314463000'),
#                'Liquidez': Decimal('454770'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BPML11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('92.72'),
#                'FFO Yield': Decimal('-1.44'),
#                'Dividend Yield': Decimal('6.13'),
#                'P/VP': Decimal('0.79'),
#                'Valor de Mercado': Decimal('689999000'),
#                'Liquidez': Decimal('1224420'),
#                'Qtd de imóveis': Decimal('4'),
#                'Preço do m2': Decimal('5499.35'),
#                'Aluguel por m2': Decimal('844.54'),
#                'Cap Rate': Decimal('15.36'),
#                'Vacância Média': Decimal('6.97')}),
#              ('BPRP11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('108.52'),
#                'FFO Yield': Decimal('10.33'),
#                'Dividend Yield': Decimal('10.36'),
#                'P/VP': Decimal('0.86'),
#                'Valor de Mercado': Decimal('146484000'),
#                'Liquidez': Decimal('3000'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('6295.22'),
#                'Aluguel por m2': Decimal('684.18'),
#                'Cap Rate': Decimal('10.87'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BRCO11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('112.03'),
#                'FFO Yield': Decimal('6.89'),
#                'Dividend Yield': Decimal('9.08'),
#                'P/VP': Decimal('0.94'),
#                'Valor de Mercado': Decimal('1781850000'),
#                'Liquidez': Decimal('3571050'),
#                'Qtd de imóveis': Decimal('10'),
#                'Preço do m2': Decimal('4143.88'),
#                'Aluguel por m2': Decimal('375.46'),
#                'Cap Rate': Decimal('9.06'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BRCR11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('49.42'),
#                'FFO Yield': Decimal('1.71'),
#                'Dividend Yield': Decimal('10.57'),
#                'P/VP': Decimal('0.55'),
#                'Valor de Mercado': Decimal('1316460000'),
#                'Liquidez': Decimal('1811680'),
#                'Qtd de imóveis': Decimal('9'),
#                'Preço do m2': Decimal('8817.54'),
#                'Aluguel por m2': Decimal('1278.12'),
#                'Cap Rate': Decimal('14.50'),
#                'Vacância Média': Decimal('5.71')}),
#              ('BREV11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('105.00'),
#                'FFO Yield': Decimal('6.59'),
#                'Dividend Yield': Decimal('1.64'),
#                'P/VP': Decimal('0.00'),
#                'Valor de Mercado': Decimal('101556000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('13'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('1437.55'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BRIM11',
#               {'Segmento': 'Residencial',
#                'Cotacao': Decimal('1081.92'),
#                'FFO Yield': Decimal('13.00'),
#                'Dividend Yield': Decimal('17.57'),
#                'P/VP': Decimal('1.13'),
#                'Valor de Mercado': Decimal('134306000'),
#                'Liquidez': Decimal('1713'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BRIP11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('968.99'),
#                'FFO Yield': Decimal('-2.03'),
#                'Dividend Yield': Decimal('21.53'),
#                'P/VP': Decimal('1.04'),
#                'Valor de Mercado': Decimal('208793000'),
#                'Liquidez': Decimal('1594'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BRLA11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('159.00'),
#                'FFO Yield': Decimal('7.76'),
#                'Dividend Yield': Decimal('8.14'),
#                'P/VP': Decimal('1.00'),
#                'Valor de Mercado': Decimal('564211000'),
#                'Liquidez': Decimal('36846'),
#                'Qtd de imóveis': Decimal('8'),
#                'Preço do m2': Decimal('1669.48'),
#                'Aluguel por m2': Decimal('134.99'),
#                'Cap Rate': Decimal('8.09'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BROF11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('51.97'),
#                'FFO Yield': Decimal('13.84'),
#                'Dividend Yield': Decimal('12.14'),
#                'P/VP': Decimal('0.49'),
#                'Valor de Mercado': Decimal('603414000'),
#                'Liquidez': Decimal('583598'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('6525.26'),
#                'Aluguel por m2': Decimal('1055.77'),
#                'Cap Rate': Decimal('16.18'),
#                'Vacância Média': Decimal('4.15')}),
#              ('BTAL11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('76.00'),
#                'FFO Yield': Decimal('10.34'),
#                'Dividend Yield': Decimal('10.50'),
#                'P/VP': Decimal('0.70'),
#                'Valor de Mercado': Decimal('454688000'),
#                'Liquidez': Decimal('682871'),
#                'Qtd de imóveis': Decimal('9'),
#                'Preço do m2': Decimal('1360.40'),
#                'Aluguel por m2': Decimal('172.25'),
#                'Cap Rate': Decimal('12.66'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTCI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('9.92'),
#                'FFO Yield': Decimal('11.29'),
#                'Dividend Yield': Decimal('11.72'),
#                'P/VP': Decimal('0.97'),
#                'Valor de Mercado': Decimal('987250000'),
#                'Liquidez': Decimal('2257000'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTCR11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('88.00'),
#                'FFO Yield': Decimal('12.48'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.92'),
#                'Valor de Mercado': Decimal('423289000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTHI11',
#               {'Segmento': 'Hotel',
#                'Cotacao': Decimal('38.49'),
#                'FFO Yield': Decimal('11.00'),
#                'Dividend Yield': Decimal('8.63'),
#                'P/VP': Decimal('0.61'),
#                'Valor de Mercado': Decimal('354821000'),
#                'Liquidez': Decimal('30539'),
#                'Qtd de imóveis': Decimal('12'),
#                'Preço do m2': Decimal('684.76'),
#                'Aluguel por m2': Decimal('88.01'),
#                'Cap Rate': Decimal('12.85'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTLG11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('101.45'),
#                'FFO Yield': Decimal('4.31'),
#                'Dividend Yield': Decimal('8.61'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('4387630000'),
#                'Liquidez': Decimal('10548800'),
#                'Qtd de imóveis': Decimal('21'),
#                'Preço do m2': Decimal('3306.04'),
#                'Aluguel por m2': Decimal('213.45'),
#                'Cap Rate': Decimal('6.46'),
#                'Vacância Média': Decimal('2.43')}),
#              ('BTML11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('111.28'),
#                'FFO Yield': Decimal('7.18'),
#                'Dividend Yield': Decimal('5.17'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('126321000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('22272.20'),
#                'Aluguel por m2': Decimal('3199.80'),
#                'Cap Rate': Decimal('14.37'),
#                'Vacância Média': Decimal('9.70')}),
#              ('BTRA11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('54.81'),
#                'FFO Yield': Decimal('44.09'),
#                'Dividend Yield': Decimal('8.81'),
#                'P/VP': Decimal('0.50'),
#                'Valor de Mercado': Decimal('184411000'),
#                'Liquidez': Decimal('471051'),
#                'Qtd de imóveis': Decimal('6'),
#                'Preço do m2': Decimal('2.05'),
#                'Aluguel por m2': Decimal('0.26'),
#                'Cap Rate': Decimal('12.45'),
#                'Vacância Média': Decimal('30.27')}),
#              ('BTSG11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('159.08'),
#                'FFO Yield': Decimal('10.21'),
#                'Dividend Yield': Decimal('6.62'),
#                'P/VP': Decimal('1.10'),
#                'Valor de Mercado': Decimal('123289000'),
#                'Liquidez': Decimal('150'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('6537.44'),
#                'Aluguel por m2': Decimal('726.41'),
#                'Cap Rate': Decimal('11.11'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTSI11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('105.50'),
#                'FFO Yield': Decimal('6.72'),
#                'Dividend Yield': Decimal('7.55'),
#                'P/VP': Decimal('0.97'),
#                'Valor de Mercado': Decimal('337619000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('3'),
#                'Preço do m2': Decimal('1112.35'),
#                'Aluguel por m2': Decimal('122.80'),
#                'Cap Rate': Decimal('11.04'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BTWR11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('125.00'),
#                'FFO Yield': Decimal('5.41'),
#                'Dividend Yield': Decimal('5.55'),
#                'P/VP': Decimal('1.11'),
#                'Valor de Mercado': Decimal('101159000'),
#                'Liquidez': Decimal('19'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('5070.09'),
#                'Aluguel por m2': Decimal('406.78'),
#                'Cap Rate': Decimal('8.02'),
#                'Vacância Média': Decimal('4.00')}),
#              ('BTYU11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('10.13'),
#                'FFO Yield': Decimal('0.00'),
#                'Dividend Yield': Decimal('0.85'),
#                'P/VP': Decimal('1.00'),
#                'Valor de Mercado': Decimal('202600000'),
#                'Liquidez': Decimal('918680'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('BVAR11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('1390.00'),
#                'FFO Yield': Decimal('6.29'),
#                'Dividend Yield': Decimal('4.71'),
#                'P/VP': Decimal('1.55'),
#                'Valor de Mercado': Decimal('869501000'),
#                'Liquidez': Decimal('642'),
#                'Qtd de imóveis': Decimal('49'),
#                'Preço do m2': Decimal('7885.39'),
#                'Aluguel por m2': Decimal('551.35'),
#                'Cap Rate': Decimal('6.99'),
#                'Vacância Média': Decimal('27.50')}),
#              ('CACR11',
#               {'Segmento': None,
#                'Cotacao': Decimal('103.52'),
#                'FFO Yield': Decimal('7.40'),
#                'Dividend Yield': Decimal('14.86'),
#                'P/VP': Decimal('1.04'),
#                'Valor de Mercado': Decimal('395836000'),
#                'Liquidez': Decimal('1545120'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CARE11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('1.67'),
#                'FFO Yield': Decimal('-8.91'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.21'),
#                'Valor de Mercado': Decimal('59735800'),
#                'Liquidez': Decimal('11690'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CBOP11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('27.73'),
#                'FFO Yield': Decimal('6.79'),
#                'Dividend Yield': Decimal('5.30'),
#                'P/VP': Decimal('0.38'),
#                'Valor de Mercado': Decimal('39238000'),
#                'Liquidez': Decimal('7999'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('2394.78'),
#                'Aluguel por m2': Decimal('342.94'),
#                'Cap Rate': Decimal('14.32'),
#                'Vacância Média': Decimal('53.40')}),
#              ('CCME11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('12.50'),
#                'FFO Yield': Decimal('5.21'),
#                'Dividend Yield': Decimal('8.74'),
#                'P/VP': Decimal('1.17'),
#                'Valor de Mercado': Decimal('847463000'),
#                'Liquidez': Decimal('39713'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('8064.45'),
#                'Aluguel por m2': Decimal('401.89'),
#                'Cap Rate': Decimal('4.98'),
#                'Vacância Média': Decimal('6.15')}),
#              ('CCRF11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('92.50'),
#                'FFO Yield': Decimal('7.16'),
#                'Dividend Yield': Decimal('4.02'),
#                'P/VP': Decimal('0.95'),
#                'Valor de Mercado': Decimal('145401000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CEOC11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('43.84'),
#                'FFO Yield': Decimal('13.67'),
#                'Dividend Yield': Decimal('12.85'),
#                'P/VP': Decimal('0.60'),
#                'Valor de Mercado': Decimal('79600100'),
#                'Liquidez': Decimal('27566'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('4993.37'),
#                'Aluguel por m2': Decimal('812.73'),
#                'Cap Rate': Decimal('16.28'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CFHI11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('650.00'),
#                'FFO Yield': Decimal('26.39'),
#                'Dividend Yield': Decimal('20.41'),
#                'P/VP': Decimal('1.02'),
#                'Valor de Mercado': Decimal('61490000'),
#                'Liquidez': Decimal('77'),
#                'Qtd de imóveis': Decimal('10'),
#                'Preço do m2': Decimal('4747.82'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CFII11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('1000.00'),
#                'FFO Yield': Decimal('-1.38'),
#                'Dividend Yield': Decimal('10.80'),
#                'P/VP': Decimal('0.96'),
#                'Valor de Mercado': Decimal('100634000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('4'),
#                'Preço do m2': Decimal('5611.87'),
#                'Aluguel por m2': Decimal('107.75'),
#                'Cap Rate': Decimal('1.92'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CJCT11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('64.49'),
#                'FFO Yield': Decimal('3.03'),
#                'Dividend Yield': Decimal('2.54'),
#                'P/VP': Decimal('0.90'),
#                'Valor de Mercado': Decimal('202499000'),
#                'Liquidez': Decimal('20578'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('10260.00'),
#                'Aluguel por m2': Decimal('630.90'),
#                'Cap Rate': Decimal('6.15'),
#                'Vacância Média': Decimal('49.67')}),
#              ('CLIN11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('96.68'),
#                'FFO Yield': Decimal('5.05'),
#                'Dividend Yield': Decimal('8.99'),
#                'P/VP': Decimal('0.98'),
#                'Valor de Mercado': Decimal('420245000'),
#                'Liquidez': Decimal('1410430'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('CNES11',
# ...
#                'Vacância Média': Decimal('0.00')}),
#              ('VTLT11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('93.15'),
#                'FFO Yield': Decimal('11.81'),
#                'Dividend Yield': Decimal('10.98'),
#                'P/VP': Decimal('0.83'),
#                'Valor de Mercado': Decimal('197012000'),
#                'Liquidez': Decimal('99696'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('765.13'),
#                'Aluguel por m2': Decimal('102.41'),
#                'Cap Rate': Decimal('13.38'),
#                'Vacância Média': Decimal('0.00')}),
#              ('VTPL11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('72.10'),
#                'FFO Yield': Decimal('-0.63'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.00'),
#                'Valor de Mercado': Decimal('99948000'),
#                'Liquidez': Decimal('188'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('1174.16'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('VVCR11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('9.96'),
#                'FFO Yield': Decimal('4.77'),
#                'Dividend Yield': Decimal('11.72'),
#                'P/VP': Decimal('0.91'),
#                'Valor de Mercado': Decimal('74783000'),
#                'Liquidez': Decimal('276126'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('VVMR11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('91.11'),
#                'FFO Yield': Decimal('6.92'),
#                'Dividend Yield': Decimal('6.23'),
#                'P/VP': Decimal('0.78'),
#                'Valor de Mercado': Decimal('252576000'),
#                'Liquidez': Decimal('504920'),
#                'Qtd de imóveis': Decimal('5'),
#                'Preço do m2': Decimal('8052.68'),
#                'Aluguel por m2': Decimal('702.85'),
#                'Cap Rate': Decimal('8.73'),
#                'Vacância Média': Decimal('2.83')}),
#              ('VVPR11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('101.50'),
#                'FFO Yield': Decimal('8.99'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.04'),
#                'Valor de Mercado': Decimal('234036000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('6'),
#                'Preço do m2': Decimal('5334.39'),
#                'Aluguel por m2': Decimal('526.70'),
#                'Cap Rate': Decimal('9.87'),
#                'Vacância Média': Decimal('0.00')}),
#              ('VVRI11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('109.90'),
#                'FFO Yield': Decimal('7.07'),
#                'Dividend Yield': Decimal('12.36'),
#                'P/VP': Decimal('1.08'),
#                'Valor de Mercado': Decimal('88214900'),
#                'Liquidez': Decimal('3233'),
#                'Qtd de imóveis': Decimal('2'),
#                'Preço do m2': Decimal('5619.77'),
#                'Aluguel por m2': Decimal('462.57'),
#                'Cap Rate': Decimal('8.23'),
#                'Vacância Média': Decimal('0.00')}),
#              ('VXXV11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('673.00'),
#                'FFO Yield': Decimal('-1.10'),
#                'Dividend Yield': Decimal('35.50'),
#                'P/VP': Decimal('0.84'),
#                'Valor de Mercado': Decimal('180866000'),
#                'Liquidez': Decimal('1323120'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('WHGR11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('9.62'),
#                'FFO Yield': Decimal('10.85'),
#                'Dividend Yield': Decimal('11.77'),
#                'P/VP': Decimal('0.99'),
#                'Valor de Mercado': Decimal('256976000'),
#                'Liquidez': Decimal('555960'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('WPLZ11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('61.50'),
#                'FFO Yield': Decimal('8.31'),
#                'Dividend Yield': Decimal('7.69'),
#                'P/VP': Decimal('0.69'),
#                'Valor de Mercado': Decimal('65469800'),
#                'Liquidez': Decimal('2839'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('1746.42'),
#                'Aluguel por m2': Decimal('158.61'),
#                'Cap Rate': Decimal('9.08'),
#                'Vacância Média': Decimal('15.85')}),
#              ('WSEC11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('87.95'),
#                'FFO Yield': Decimal('13.53'),
#                'Dividend Yield': Decimal('13.30'),
#                'P/VP': Decimal('0.87'),
#                'Valor de Mercado': Decimal('21605000'),
#                'Liquidez': Decimal('15269'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('WTSP11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('42.00'),
#                'FFO Yield': Decimal('8.87'),
#                'Dividend Yield': Decimal('9.28'),
#                'P/VP': Decimal('0.52'),
#                'Valor de Mercado': Decimal('41687700'),
#                'Liquidez': Decimal('1229'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('3399.92'),
#                'Aluguel por m2': Decimal('293.35'),
#                'Cap Rate': Decimal('8.63'),
#                'Vacância Média': Decimal('4.35')}),
#              ('XPCA11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('7.95'),
#                'FFO Yield': Decimal('15.72'),
#                'Dividend Yield': Decimal('15.23'),
#                'P/VP': Decimal('0.84'),
#                'Valor de Mercado': Decimal('361908000'),
#                'Liquidez': Decimal('1455210'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('XPCI11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('87.30'),
#                'FFO Yield': Decimal('11.83'),
#                'Dividend Yield': Decimal('12.59'),
#                'P/VP': Decimal('0.97'),
#                'Valor de Mercado': Decimal('759646000'),
#                'Liquidez': Decimal('2199250'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('XPCM11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('8.40'),
#                'FFO Yield': Decimal('-3.54'),
#                'Dividend Yield': Decimal('4.32'),
#                'P/VP': Decimal('0.29'),
#                'Valor de Mercado': Decimal('20282400'),
#                'Liquidez': Decimal('26330'),
#                'Qtd de imóveis': Decimal('1'),
#                'Preço do m2': Decimal('991.49'),
#                'Aluguel por m2': Decimal('9.62'),
#                'Cap Rate': Decimal('0.97'),
#                'Vacância Média': Decimal('81.00')}),
#              ('XPHT11',
#               {'Segmento': 'Hotel',
#                'Cotacao': Decimal('123.00'),
#                'FFO Yield': Decimal('3.44'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('1.95'),
#                'Valor de Mercado': Decimal('1133880000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('12'),
#                'Preço do m2': Decimal('2188.25'),
#                'Aluguel por m2': Decimal('88.01'),
#                'Cap Rate': Decimal('4.02'),
#                'Vacância Média': Decimal('0.00')}),
#              ('XPIN11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('77.20'),
#                'FFO Yield': Decimal('9.22'),
#                'Dividend Yield': Decimal('9.30'),
#                'P/VP': Decimal('0.76'),
#                'Valor de Mercado': Decimal('552013000'),
#                'Liquidez': Decimal('445077'),
#                'Qtd de imóveis': Decimal('97'),
#                'Preço do m2': Decimal('2008.92'),
#                'Aluguel por m2': Decimal('202.14'),
#                'Cap Rate': Decimal('10.06'),
#                'Vacância Média': Decimal('12.21')}),
#              ('XPLG11',
#               {'Segmento': 'Logística',
#                'Cotacao': Decimal('102.95'),
#                'FFO Yield': Decimal('8.50'),
#                'Dividend Yield': Decimal('7.96'),
#                'P/VP': Decimal('0.92'),
#                'Valor de Mercado': Decimal('3048680000'),
#                'Liquidez': Decimal('5533080'),
#                'Qtd de imóveis': Decimal('19'),
#                'Preço do m2': Decimal('2331.50'),
#                'Aluguel por m2': Decimal('219.61'),
#                'Cap Rate': Decimal('9.42'),
#                'Vacância Média': Decimal('4.11')}),
#              ('XPML11',
#               {'Segmento': 'Shoppings',
#                'Cotacao': Decimal('113.50'),
#                'FFO Yield': Decimal('5.02'),
#                'Dividend Yield': Decimal('8.86'),
#                'P/VP': Decimal('1.02'),
#                'Valor de Mercado': Decimal('6278840000'),
#                'Liquidez': Decimal('16977500'),
#                'Qtd de imóveis': Decimal('15'),
#                'Preço do m2': Decimal('6192.28'),
#                'Aluguel por m2': Decimal('448.85'),
#                'Cap Rate': Decimal('7.25'),
#                'Vacância Média': Decimal('0.23')}),
#              ('XPPR11',
#               {'Segmento': 'Outros',
#                'Cotacao': Decimal('17.43'),
#                'FFO Yield': Decimal('4.89'),
#                'Dividend Yield': Decimal('5.69'),
#                'P/VP': Decimal('0.27'),
#                'Valor de Mercado': Decimal('127521000'),
#                'Liquidez': Decimal('215193'),
#                'Qtd de imóveis': Decimal('5'),
#                'Preço do m2': Decimal('1723.39'),
#                'Aluguel por m2': Decimal('356.09'),
#                'Cap Rate': Decimal('20.66'),
#                'Vacância Média': Decimal('43.71')}),
#              ('XPSF11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('7.63'),
#                'FFO Yield': Decimal('10.98'),
#                'Dividend Yield': Decimal('11.06'),
#                'P/VP': Decimal('0.90'),
#                'Valor de Mercado': Decimal('330395000'),
#                'Liquidez': Decimal('580717'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('XTED11',
#               {'Segmento': 'Lajes Corporativas',
#                'Cotacao': Decimal('8.82'),
#                'FFO Yield': Decimal('8.22'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.63'),
#                'Valor de Mercado': Decimal('87318000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('4'),
#                'Preço do m2': Decimal('11.10'),
#                'Aluguel por m2': Decimal('0.41'),
#                'Cap Rate': Decimal('3.66'),
#                'Vacância Média': Decimal('0.04')}),
#              ('YCHY11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('1000.00'),
#                'FFO Yield': Decimal('1.17'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('9.89'),
#                'Valor de Mercado': Decimal('3708170000'),
#                'Liquidez': Decimal('0'),
#                'Qtd de imóveis': Decimal('12'),
#                'Preço do m2': Decimal('14069.20'),
#                'Aluguel por m2': Decimal('124.53'),
#                'Cap Rate': Decimal('0.89'),
#                'Vacância Média': Decimal('3.74')}),
#              ('YUFI11',
#               {'Segmento': 'Residencial',
#                'Cotacao': Decimal('89.84'),
#                'FFO Yield': Decimal('3.84'),
#                'Dividend Yield': Decimal('3.59'),
#                'P/VP': Decimal('0.85'),
#                'Valor de Mercado': Decimal('44259700'),
#                'Liquidez': Decimal('4'),
#                'Qtd de imóveis': Decimal('40'),
#                'Preço do m2': Decimal('2194.43'),
#                'Aluguel por m2': Decimal('240.60'),
#                'Cap Rate': Decimal('10.96'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ZAGH11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('12.00'),
#                'FFO Yield': Decimal('41.06'),
#                'Dividend Yield': Decimal('1.24'),
#                'P/VP': Decimal('0.12'),
#                'Valor de Mercado': Decimal('5575150'),
#                'Liquidez': Decimal('465'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ZAVC11',
#               {'Segmento': 'Títulos e Val. Mob.',
#                'Cotacao': Decimal('10.01'),
#                'FFO Yield': Decimal('0.16'),
#                'Dividend Yield': Decimal('3.63'),
#                'P/VP': Decimal('1.01'),
#                'Valor de Mercado': Decimal('31004500'),
#                'Liquidez': Decimal('116376'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')}),
#              ('ZAVI11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('103.74'),
#                'FFO Yield': Decimal('13.02'),
#                'Dividend Yield': Decimal('14.00'),
#                'P/VP': Decimal('0.78'),
#                'Valor de Mercado': Decimal('121720000'),
#                'Liquidez': Decimal('422766'),
#                'Qtd de imóveis': Decimal('11'),
#                'Preço do m2': Decimal('1541.49'),
#                'Aluguel por m2': Decimal('185.28'),
#                'Cap Rate': Decimal('12.02'),
#                'Vacância Média': Decimal('0.63')}),
#              ('ZIFI11',
#               {'Segmento': 'Híbrido',
#                'Cotacao': Decimal('670.00'),
#                'FFO Yield': Decimal('-1.87'),
#                'Dividend Yield': Decimal('0.00'),
#                'P/VP': Decimal('0.34'),
#                'Valor de Mercado': Decimal('31815000'),
#                'Liquidez': Decimal('2817'),
#                'Qtd de imóveis': Decimal('0'),
#                'Preço do m2': Decimal('0.00'),
#                'Aluguel por m2': Decimal('0.00'),
#                'Cap Rate': Decimal('0.00'),
#                'Vacância Média': Decimal('0.00')})])

# %%
papeis = {
    'Papel': [],
    'Segmento': [],
    'Cotacao': [],
    'FFO Yield': [],
    'Dividend Yield': [],
    'P/VP': [],
    'Valor de Mercado': [],
    'Liquidez': [],
    'Qtd de imóveis': [],
    'Preço do m2': [],
    'Aluguel por m2': [],
    'Cap Rate': [],
    'Vacância Média': []}

for papel, info in data.items():
    papeis['Papel'].append(papel)
    papeis['Segmento'].append(info['Segmento'])
    papeis['Cotacao'].append(info['Cotacao'])
    papeis['FFO Yield'].append(info['FFO Yield'])
    papeis['Dividend Yield'].append(info['Dividend Yield'])
    papeis['P/VP'].append(info['P/VP'])
    papeis['Valor de Mercado'].append(info['Valor de Mercado'])
    papeis['Liquidez'].append(info['Liquidez'])
    papeis['Qtd de imóveis'].append(info['Qtd de imóveis'])
    papeis['Preço do m2'].append(info['Preço do m2'])
    papeis['Aluguel por m2'].append(info['Aluguel por m2'])
    papeis['Cap Rate'].append(info['Cap Rate'])
    papeis['Vacância Média'].append(info['Vacância Média'])

df_fii = pd.DataFrame(papeis)
df_fii
# Out:
#       Papel             Segmento Cotacao FFO Yield Dividend Yield  P/VP  \
# 0    AAZQ11  Títulos e Val. Mob.    7.39     20.37          17.51  0.78
# 1    ABCP11            Shoppings   67.50     10.17           9.25  0.67
# 2    AEFI11               Outros  174.90      8.78           0.00  1.20
# 3    AFCR11                 None  103.15      7.43           0.00  1.03
# 4    AFHI11  Títulos e Val. Mob.   97.17      9.76          11.51  1.01
# ..      ...                  ...     ...       ...            ...   ...
# 466  YUFI11          Residencial   89.84      3.84           3.59  0.85
# 467  ZAGH11              Híbrido   12.00     41.06           1.24  0.12
# 468  ZAVC11  Títulos e Val. Mob.   10.01      0.16           3.63  1.01
# 469  ZAVI11              Híbrido  103.74     13.02          14.00  0.78
# 470  ZIFI11              Híbrido  670.00     -1.87           0.00  0.34
#
#     Valor de Mercado Liquidez Qtd de imóveis Preço do m2 Aluguel por m2  \
# 0          177636000  1261870              0        0.00           0.00
# 1          317863000    57613              1     4442.43         567.65
# 2          411893000        0              7     4312.36         390.35
# 3          394422000        0              0        0.00           0.00
# 4          388384000  1484810              0        0.00           0.00
# ..               ...      ...            ...         ...            ...
# 466         44259700        4             40     2194.43         240.60
# 467          5575150      465              0        0.00           0.00
# 468         31004500   116376              0        0.00           0.00
# 469        121720000   422766             11     1541.49         185.28
# 470         31815000     2817              0        0.00           0.00
#
#     Cap Rate Vacância Média
# 0       0.00           0.00
# 1      12.78           2.44
# 2       9.05           0.00
# 3       0.00           0.00
# 4       0.00           0.00
# ..       ...            ...
# 466    10.96           0.00
# 467     0.00           0.00
# 468     0.00           0.00
# 469    12.02           0.63
# 470     0.00           0.00
#
# [471 rows x 13 columns]

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# ## Removendo valores nulos

# %%
df_fii.isnull().sum()
# Out:
# Papel               0
# Segmento            4
# Cotacao             0
# FFO Yield           0
# Dividend Yield      0
# P/VP                0
# Valor de Mercado    0
# Liquidez            0
# Qtd de imóveis      0
# Preço do m2         0
# Aluguel por m2      0
# Cap Rate            0
# Vacância Média      0
# dtype: int64

# %%
df_fii.dropna(inplace=True)
df_fii
# Out:
#       Papel             Segmento Cotacao FFO Yield Dividend Yield   P/VP  \
# 0    AAZQ11  Títulos e Val. Mob.    7.39     20.37          17.51   0.78
# 1    ABCP11            Shoppings   67.50     10.17           9.25   0.67
# 2    AEFI11               Outros  174.90      8.78           0.00   1.20
# 4    AFHI11  Títulos e Val. Mob.   97.17      9.76          11.51   1.01
# 5    AFOF11  Títulos e Val. Mob.   91.60      0.63           0.00  10.91
# ..      ...                  ...     ...       ...            ...    ...
# 466  YUFI11          Residencial   89.84      3.84           3.59   0.85
# 467  ZAGH11              Híbrido   12.00     41.06           1.24   0.12
# 468  ZAVC11  Títulos e Val. Mob.   10.01      0.16           3.63   1.01
# 469  ZAVI11              Híbrido  103.74     13.02          14.00   0.78
# 470  ZIFI11              Híbrido  670.00     -1.87           0.00   0.34
#
#     Valor de Mercado Liquidez Qtd de imóveis Preço do m2 Aluguel por m2  \
# 0          177636000  1261870              0        0.00           0.00
# 1          317863000    57613              1     4442.43         567.65
# 2          411893000        0              7     4312.36         390.35
# 4          388384000  1484810              0        0.00           0.00
# 5         1390540000        0              0        0.00           0.00
# ..               ...      ...            ...         ...            ...
# 466         44259700        4             40     2194.43         240.60
# 467          5575150      465              0        0.00           0.00
# 468         31004500   116376              0        0.00           0.00
# 469        121720000   422766             11     1541.49         185.28
# 470         31815000     2817              0        0.00           0.00
#
#     Cap Rate Vacância Média
# 0       0.00           0.00
# 1      12.78           2.44
# 2       9.05           0.00
# 4       0.00           0.00
# 5       0.00           0.00
# ..       ...            ...
# 466    10.96           0.00
# 467     0.00           0.00
# 468     0.00           0.00
# 469    12.02           0.63
# 470     0.00           0.00
#
# [467 rows x 13 columns]

# %% [markdown]
# ## Removendo valores com liquidez 0 pois são fundos interrompidos

# %%
df_fii['Liquidez'] = df_fii['Liquidez'].replace(0, '')
df_fii['Liquidez'] = pd.to_numeric(df_fii['Liquidez'], errors='coerce')
df_fii
# Out:
#       Papel             Segmento Cotacao FFO Yield Dividend Yield   P/VP  \
# 0    AAZQ11  Títulos e Val. Mob.    7.39     20.37          17.51   0.78
# 1    ABCP11            Shoppings   67.50     10.17           9.25   0.67
# 2    AEFI11               Outros  174.90      8.78           0.00   1.20
# 4    AFHI11  Títulos e Val. Mob.   97.17      9.76          11.51   1.01
# 5    AFOF11  Títulos e Val. Mob.   91.60      0.63           0.00  10.91
# ..      ...                  ...     ...       ...            ...    ...
# 466  YUFI11          Residencial   89.84      3.84           3.59   0.85
# 467  ZAGH11              Híbrido   12.00     41.06           1.24   0.12
# 468  ZAVC11  Títulos e Val. Mob.   10.01      0.16           3.63   1.01
# 469  ZAVI11              Híbrido  103.74     13.02          14.00   0.78
# 470  ZIFI11              Híbrido  670.00     -1.87           0.00   0.34
#
#     Valor de Mercado   Liquidez Qtd de imóveis Preço do m2 Aluguel por m2  \
# 0          177636000  1261870.0              0        0.00           0.00
# 1          317863000    57613.0              1     4442.43         567.65
# 2          411893000        NaN              7     4312.36         390.35
# 4          388384000  1484810.0              0        0.00           0.00
# 5         1390540000        NaN              0        0.00           0.00
# ..               ...        ...            ...         ...            ...
# 466         44259700        4.0             40     2194.43         240.60
# 467          5575150      465.0              0        0.00           0.00
# 468         31004500   116376.0              0        0.00           0.00
# 469        121720000   422766.0             11     1541.49         185.28
# 470         31815000     2817.0              0        0.00           0.00
#
#     Cap Rate Vacância Média
# 0       0.00           0.00
# 1      12.78           2.44
# 2       9.05           0.00
# 4       0.00           0.00
# 5       0.00           0.00
# ..       ...            ...
# 466    10.96           0.00
# 467     0.00           0.00
# 468     0.00           0.00
# 469    12.02           0.63
# 470     0.00           0.00
#
# [467 rows x 13 columns]

# %%
df_fii.isnull().sum()
# Out:
# Papel                 0
# Segmento              0
# Cotacao               0
# FFO Yield             0
# Dividend Yield        0
# P/VP                  0
# Valor de Mercado      0
# Liquidez            107
# Qtd de imóveis        0
# Preço do m2           0
# Aluguel por m2        0
# Cap Rate              0
# Vacância Média        0
# dtype: int64

# %%
df_fii.dropna(inplace=True)

# %% [markdown]
# ## Convertendo valores para % nos campos aplicáveis

# %% [markdown]
# ### Testando método de conversão

# %%
#df_fii['Dividend Yield'] = df_fii['Dividend Yield'].apply(lambda x: f'{x:.2f}%')
#df_fii['FFO Yield'] = df_fii['FFO Yield'].apply(lambda x: f'{x:.2f}%')
#df_fii['Cap Rate'] = df_fii['Cap Rate'].apply(lambda x: f'{x:.2f}%')
#df_fii['Vacância Média'] = df_fii['Vacância Média'].apply(lambda x: f'{x:.2f}%')

# %% [markdown]
# ### Após método de conversão testado, transformação em função

# %%
def format_to_percent_column (df,col_name):
    df[col_name] = df[col_name].apply(lambda x: f'{x:.2f}%')

columns_format = ['Dividend Yield', 'FFO Yield','Cap Rate','Vacância Média']

for col in columns_format:
    format_to_percent_column(df_fii, col)

df_fii
# Out:
#       Papel             Segmento Cotacao FFO Yield Dividend Yield  P/VP  \
# 0    AAZQ11  Títulos e Val. Mob.    7.39    20.37%         17.51%  0.78
# 1    ABCP11            Shoppings   67.50    10.17%          9.25%  0.67
# 4    AFHI11  Títulos e Val. Mob.   97.17     9.76%         11.51%  1.01
# 7    AGRX11              Híbrido    9.71    13.84%         16.55%  0.96
# 8    AIEC11   Lajes Corporativas   53.21    19.00%         17.66%  0.63
# ..      ...                  ...     ...       ...            ...   ...
# 466  YUFI11          Residencial   89.84     3.84%          3.59%  0.85
# 467  ZAGH11              Híbrido   12.00    41.06%          1.24%  0.12
# 468  ZAVC11  Títulos e Val. Mob.   10.01     0.16%          3.63%  1.01
# 469  ZAVI11              Híbrido  103.74    13.02%         14.00%  0.78
# 470  ZIFI11              Híbrido  670.00    -1.87%          0.00%  0.34
#
#     Valor de Mercado   Liquidez Qtd de imóveis Preço do m2 Aluguel por m2  \
# 0          177636000  1261870.0              0        0.00           0.00
# 1          317863000    57613.0              1     4442.43         567.65
# 4          388384000  1484810.0              0        0.00           0.00
# 7          173840000   295761.0              0        0.00           0.00
# 8          256738000   337791.0              2    10715.20        2098.55
# ..               ...        ...            ...         ...            ...
# 466         44259700        4.0             40     2194.43         240.60
# 467          5575150      465.0              0        0.00           0.00
# 468         31004500   116376.0              0        0.00           0.00
# 469        121720000   422766.0             11     1541.49         185.28
# 470         31815000     2817.0              0        0.00           0.00
#
#     Cap Rate Vacância Média
# 0      0.00%          0.00%
# 1     12.78%          2.44%
# 4      0.00%          0.00%
# 7      0.00%          0.00%
# 8     19.58%          0.00%
# ..       ...            ...
# 466   10.96%          0.00%
# 467    0.00%          0.00%
# 468    0.00%          0.00%
# 469   12.02%          0.63%
# 470    0.00%          0.00%
#
# [360 rows x 13 columns]

# %% [markdown]
# # Exportação

# %%
df_fii.to_csv('data_fund\\fiis_fund.csv', index=False)
df_fii['Papel'].to_csv('data_fund\\fiis_tickers.csv', index=False)
