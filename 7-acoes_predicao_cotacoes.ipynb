# %%
import pandas as pd
import numpy as np

# %%
df_cotacoes_justas = pd.read_csv("C:\\Users\\Matheus Poletto\\Desktop\\Cientista de Dados\\ACOES-E-FIIS\\cotacoes_justas.csv")
df_cotacoes_atuais = pd.read_csv("C:\\Users\\Matheus Poletto\\Desktop\\Cientista de Dados\\ACOES-E-FIIS\\stocks_rvi_fund_07-01-2025.csv")

# %%
df_cotacoes_justas = df_cotacoes_justas.rename(columns={'Cotacao': 'Cotacao_justa'})
df_cotacoes_justas
# Out:
#     ticker  Cotacao_justa
# 0    MMAQ3    1413.811200
# 1    HETA3     122.166970
# 2    PRIO3      89.530320
# 3    MMAQ4    1413.811200
# 4    NUTR3      69.315250
# ..     ...            ...
# 351  SLED3      17.267150
# 352  SLED4      17.267150
# 353  OIBR3      22.097744
# 354  AMER3     -63.605330
# 355  PDGR3      15.625277
#
# [356 rows x 2 columns]

# %%
#df_cotacoes_atuais = df_cotacoes_atuais[['ticker', 'Cotacao']]
df_cotacoes_atuais = df_cotacoes_atuais.rename(columns={'Cotacao': 'Cotacao_atual'})

df_cotacoes_atuais
# Out:
#     ticker  Cotacao_atual    P/L  P/VP     PSR     DY  P/Ativo  P/Cap.Giro  \
# 0    MMAQ3        2550.01   2.83  0.33   0.075  0.00%    0.144        0.51
# 1    HETA3          96.00  60.97 -0.14  11.769  0.00%    3.356      -63.50
# 2    PRIO3          41.63   7.61  2.05   2.645  0.00%    0.862        2.70
# 3    MMAQ4        2550.01   2.83  0.33   0.075  7.36%    0.144        0.51
# 4    NUTR3           3.99   6.93  1.30   0.280  0.00%    0.446        1.46
# ..     ...            ...    ...   ...     ...    ...      ...         ...
# 351  SLED3           3.21   0.45 -0.08   0.416  0.00%    0.480       -0.20
# 352  SLED4           1.60   0.22 -0.04   0.207  0.00%    0.239       -0.10
# 353  OIBR3           1.36   0.04 -0.03   0.051  0.00%    0.022       -0.22
# 354  AMER3           5.71   0.10  0.20   0.078  0.00%    0.062        0.38
# 355  PDGR3           0.01   0.01 -0.01   0.152  0.00%    0.032       -0.03
#
# ...

# %%
# Merge das tabelas no ticker
df_completo = pd.merge(df_cotacoes_justas, df_cotacoes_atuais, on='ticker')

# Criação da variável de valorização
df_completo["Potencial Upside/Downside (%)"] = (1-(df_completo['Cotacao_atual']/df_completo['Cotacao_justa']))*100

# Obter a coluna 'Potencial Upside/Downside (%)'
coluna = df_completo.pop('Potencial Upside/Downside (%)')

# Inserir a coluna na terceira posição (índice 2)
df_completo.insert(2, 'Potencial Upside/Downside (%)', coluna)

# Ordenando conforme variável criada
df_completo = df_completo.sort_values(by='Potencial Upside/Downside (%)', ascending=False)

#df_completo[df_completo['ticker'] == 'PRIO3']

# %%
df_completo
# Out:
#      ticker  Cotacao_justa  Potencial Upside/Downside (%)  Cotacao_atual  \
# 336   BDLL3     -63.605330                     118.866343          12.00
# 302   BDLL4     -70.966606                     111.836553           8.40
# 354   AMER3     -63.605330                     108.977235           5.71
# 355   PDGR3      15.625277                      99.936001           0.01
# 199   SJOS4      15.776716                      99.429539           0.09
# ..      ...            ...                            ...            ...
# 3     MMAQ4    1413.811200                     -80.364252        2550.01
# 0     MMAQ3    1413.811200                     -80.364252        2550.01
# 18    FRIO3     142.639710                    -110.467338         300.21
# 200  DAGB33     170.431150                    -120.030200         375.00
# 207   APTI4    1408.894800                    -148.421671        3500.00
#
#        P/L  P/VP    PSR     DY  P/Ativo  P/Cap.Giro  ...          LPA  \
# ...

# %%
df_completo.to_csv('final_product_cotacoes_differentials.csv', index=False)
