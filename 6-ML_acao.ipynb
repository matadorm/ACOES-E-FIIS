# %%
import pandas as pd
import numpy as np
import ydf

# %%
ds_train = pd.read_csv("C:\\Users\\Matheus Poletto\\Desktop\\Cientista de Dados\\ACOES-E-FIIS\\stocks_rvi_fund_07-01-2025.csv")
ds_train
# Out:
#     ticker  Cotacao    P/L  P/VP     PSR     DY  P/Ativo  P/Cap.Giro  P/EBIT  \
# 0    MMAQ3  2550.01   2.83  0.33   0.075  0.00%    0.144        0.51   -4.72
# 1    HETA3    96.00  60.97 -0.14  11.769  0.00%    3.356      -63.50   13.18
# 2    PRIO3    41.63   7.61  2.05   2.645  0.00%    0.862        2.70    5.21
# 3    MMAQ4  2550.01   2.83  0.33   0.075  7.36%    0.144        0.51   -4.72
# 4    NUTR3     3.99   6.93  1.30   0.280  0.00%    0.446        1.46    3.99
# ..     ...      ...    ...   ...     ...    ...      ...         ...     ...
# 351  SLED3     3.21   0.45 -0.08   0.416  0.00%    0.480       -0.20   -0.44
# 352  SLED4     1.60   0.22 -0.04   0.207  0.00%    0.239       -0.10   -0.22
# 353  OIBR3     1.36   0.04 -0.03   0.051  0.00%    0.022       -0.22   -0.12
# 354  AMER3     5.71   0.10  0.20   0.078  0.00%    0.062        0.38   -0.77
# 355  PDGR3     0.01   0.01 -0.01   0.152  0.00%    0.032       -0.03   -0.16
#
# ...

# %%
ydf_model = ydf.GradientBoostedTreesLearner(label="Cotacao", task=ydf.Task.REGRESSION).train(ds_train)
# Out:
# Train model on 356 examples
# Model trained in 0:00:00.073998

# %%
ydf_model.describe()
# Out:
# <style>
#
# .tab_block .header {
#     flex-direction: row;
#     display: flex;
# }
#
# .tab_block .header .tab {
#     cursor: pointer;
#     background-color: #F6F5F5;
#     text-decoration: none;
#     text-align: center;
#     padding: 4px 12px;
#     color: black;
# }
#
# .tab_block .header .tab.selected {
#     border-bottom: 2px solid #2F80ED;
# }
#
# .tab_block .header .tab:hover {
#     text-decoration: none;
#     background-color: #DCDCDC;
# }
#
# .tab_block .body .tab_content {
#     display: none;
#     padding: 5px;
# }
#
# .tab_block .body .tab_content.selected {
#     display: block;
# }
#
# .ydf_pre {
#     font-size: medium;
# }
#
#
#
# .variable_importance {
# }
#
# .variable_importance select {
# }
#
# .variable_importance .content {
#   display: none;
# }
#
# .variable_importance .content.selected {
#   display: block;
# }
#
# .ydf_tuning_table {
#   border-collapse: collapse;
#   border: 1px solid lightgray;
# }
#
# .ydf_tuning_table th {
# ...

# %%
ydf_model.analyze(ds_train, sampling=0.1)
# Out:
# <style>
#
# .tab_block .header {
#     flex-direction: row;
#     display: flex;
# }
#
# .tab_block .header .tab {
#     cursor: pointer;
#     background-color: #F6F5F5;
#     text-decoration: none;
#     text-align: center;
#     padding: 4px 12px;
#     color: black;
# }
#
# .tab_block .header .tab.selected {
#     border-bottom: 2px solid #2F80ED;
# }
#
# .tab_block .header .tab:hover {
#     text-decoration: none;
#     background-color: #DCDCDC;
# }
#
# .tab_block .body .tab_content {
#     display: none;
#     padding: 5px;
# }
#
# .tab_block .body .tab_content.selected {
#     display: block;
# }
#
# .ydf_pre {
#     font-size: medium;
# }
#
#
#
# .variable_importance {
# }
#
# .variable_importance select {
# }
#
# .variable_importance .content {
#   display: none;
# }
#
# .variable_importance .content.selected {
#   display: block;
# }
#
# .ydf_tuning_table {
#   border-collapse: collapse;
#   border: 1px solid lightgray;
# }
#
# .ydf_tuning_table th {
# ...
